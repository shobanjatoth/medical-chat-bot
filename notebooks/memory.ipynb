# %%
import os
from langchain_core.runnables import RunnableLambda
from langchain_core.prompts import ChatPromptTemplate,PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

llm = ChatGoogleGenerativeAI(
    api_key=GOOGLE_API_KEY,
    model="gemini-2.5-flash"
)

template=ChatPromptTemplate([("system","you are a helpful assistant"),
                             ("human","{query}")])

chain=template|llm

while True:
    user_input=input("you: ")
    if user_input=="exit":
        break
    result=chain.invoke({"query":user_input})
    print('bot:',result.content)
# Out:
# bot: Hi there! How can I help you today?
# bot: As an AI, I don't eat breakfast (or any other meals!). I don't have a physical body or the need for food.
#
# But thanks for asking! I appreciate the thought. 😊
# bot: Great! How can I assist you today? Feel free to ask me anything or tell me what you'd like to do.
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_interceptor.py:331, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
# --> 331 return call.result(), call
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_channel.py:438, in _InactiveRpcError.result(self, timeout)
#     437 """See grpc.Future.result."""
# --> 438 raise self
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_channel.py:1173, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 state, call = self._blocking(
#    1171     request, timeout, metadata, credentials, wait_for_ready, compression
#    1172 )
# -> 1173 return _end_unary_response_blocking(state, call, True, None)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\grpc\_channel.py:990, in _end_unary_response_blocking(state, call, with_call, deadline)
#     989     return state.response
# --> 990 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "* GenerateContentRequest.contents: contents is not specified
# "
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B2001:4860:4802:38::223%5D:443 {grpc_message:"* GenerateContentRequest.contents: contents is not specified\n", grpc_status:3}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InvalidArgument                           Traceback (most recent call last)
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:192, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     191 try:
# --> 192     return generation_method(**kwargs)
#     193 # Do not retry for these errors.
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:868, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     867 # Send the request.
# --> 868 response = rpc(
#     869     request,
#     870     retry=retry,
#     871     timeout=timeout,
#     872     metadata=metadata,
#     873 )
#     875 # Done; return the response.
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\gapic_v1\method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\retry\retry_base.py:216, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     211     final_exc, source_exc = exc_factory_fn(
#     212         error_list,
#     213         RetryFailureReason.NON_RETRYABLE_ERROR,
#     214         original_timeout,
#     215     )
# --> 216     raise final_exc from source_exc
#     217 if on_error_fn is not None:
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\google\api_core\grpc_helpers.py:57, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      56 except grpc.RpcError as exc:
# ---> 57     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 * GenerateContentRequest.contents: contents is not specified
#
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[1], line 23
#      19 while True:
#      20     user_input=input("you: ")
#      21     if user_input=="exit":
#      22         break
# ---> 23     result=chain.invoke({"query":user_input})
#      24     print('bot:',result.content)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_core\runnables\base.py:3034, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3032                 input = context.run(step.invoke, input, config, **kwargs)
#    3033             else:
# -> 3034                 input = context.run(step.invoke, input, config)
#    3035 # finish the root run
#    3036 except BaseException as e:
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1199, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1194     else:
#    1195         raise ValueError(
#    1196             "Tools are already defined." "code_execution tool can't be defined"
#    1197         )
# -> 1199 return super().invoke(input, config, stop=stop, **kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_core\language_models\chat_models.py:370, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     358 @override
#     359 def invoke(
#     360     self,
#    (...)    365     **kwargs: Any,
#     366 ) -> BaseMessage:
#     367     config = ensure_config(config)
#     368     return cast(
#     369         "ChatGeneration",
# --> 370         self.generate_prompt(
#     371             [self._convert_input(input)],
#     372             stop=stop,
#     373             callbacks=config.get("callbacks"),
#     374             tags=config.get("tags"),
#     375             metadata=config.get("metadata"),
#     376             run_name=config.get("run_name"),
#     377             run_id=config.pop("run_id", None),
#     378             **kwargs,
#     379         ).generations[0][0],
#     380     ).message
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_core\language_models\chat_models.py:947, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     938 @override
#     939 def generate_prompt(
#     940     self,
#    (...)    944     **kwargs: Any,
#     945 ) -> LLMResult:
#     946     prompt_messages = [p.to_messages() for p in prompts]
# --> 947     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_core\language_models\chat_models.py:766, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     763 for i, m in enumerate(input_messages):
#     764     try:
#     765         results.append(
# --> 766             self._generate_with_cache(
#     767                 m,
#     768                 stop=stop,
#     769                 run_manager=run_managers[i] if run_managers else None,
#     770                 **kwargs,
#     771             )
#     772         )
#     773     except BaseException as e:
#     774         if run_managers:
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_core\language_models\chat_models.py:1012, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1010     result = generate_from_stream(iter(chunks))
#    1011 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1012     result = self._generate(
#    1013         messages, stop=stop, run_manager=run_manager, **kwargs
#    1014     )
#    1015 else:
#    1016     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1275, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1249 def _generate(
#    1250     self,
#    1251     messages: List[BaseMessage],
#    (...)   1262     **kwargs: Any,
#    1263 ) -> ChatResult:
#    1264     request = self._prepare_request(
#    1265         messages,
#    1266         stop=stop,
#    (...)   1273         tool_choice=tool_choice,
#    1274     )
# -> 1275     response: GenerateContentResponse = _chat_with_retry(
#    1276         request=request,
#    1277         **kwargs,
#    1278         generation_method=self.client.generate_content,
#    1279         metadata=self.default_metadata,
#    1280     )
#    1281     return _response_to_result(response)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:210, in _chat_with_retry(generation_method, **kwargs)
#     207     except Exception as e:
#     208         raise e
# --> 210 return _chat_with_retry(**kwargs)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\tenacity\__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:204, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     201         raise ValueError(error_msg)
#     203 except google.api_core.exceptions.InvalidArgument as e:
# --> 204     raise ChatGoogleGenerativeAIError(
#     205         f"Invalid argument provided to Gemini: {e}"
#     206     ) from e
#     207 except Exception as e:
#     208     raise e
#
# ChatGoogleGenerativeAIError: Invalid argument provided to Gemini: 400 * GenerateContentRequest.contents: contents is not specified

# %% [markdown]
# # with memory

# %%
import os

from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.memory import ConversationBufferMemory
from langchain.chains import LLMChain

from langchain_google_genai import ChatGoogleGenerativeAI

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# LLM
llm = ChatGoogleGenerativeAI(
    api_key=GOOGLE_API_KEY,
    model="gemini-2.5-flash"
)

# Prompt
template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{query}")
])

# Memory
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# Chain
chain = LLMChain(
    llm=llm,
    prompt=template,
    memory=memory
)

# Chat loop
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    result = chain.invoke({
        "query": user_input
    })

    print("Bot:", result["text"])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16312\2629364204.py:25: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(
# Bot: Hi there! How can I help you today?
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot: Okay, I'll stop.
#
# Is there anything specific you'd like me to stop doing, or would you like to end our conversation? Just let me know.
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
# e:\medical_chat_bot\nayak\Lib\site-packages\langchain_google_genai\chat_models.py:1501: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# Bot:
